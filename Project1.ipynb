# %%
import pandas as pd 
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import missingno as msno
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LinearRegression
from collections import defaultdict

foodSep = {'ACCESS':pd.DataFrame, 'STORES':pd.DataFrame, 'RESTAURANTS':pd.DataFrame,'ASSISTANCE':pd.DataFrame, 
        'INSECURITY':pd.DataFrame, 'PRICES_TAXES':pd.DataFrame,
        'LOCAL':pd.DataFrame, 'HEALTH':pd.DataFrame, 'SOCIOECONOMIC':pd.DataFrame}
for k, n in foodSep.items():
    foodSep[k] = pd.read_csv(k + '.csv')

# %%
foodSep['ACCESS'].head()
# Out:
#    FIPS State   County  LACCESS_POP10  LACCESS_POP15  PCH_LACCESS_POP_10_15  \
# 0  1001    AL  Autauga   18428.439685   17496.693038              -5.056026
# 1  1003    AL  Baldwin   35210.814078   30561.264430             -13.204891
# 2  1005    AL  Barbour    5722.305602    6069.523628               6.067799
# 3  1007    AL     Bibb    1044.867327     969.378841              -7.224696
# 4  1009    AL   Blount    1548.175559    3724.428242             140.568857
#
#    PCT_LACCESS_POP10  PCT_LACCESS_POP15  LACCESS_LOWI10  LACCESS_LOWI15  \
# 0          33.769657          32.062255     5344.427472     6543.676824
# 1          19.318473          16.767489     9952.144027     9886.831137
# 2          20.840972          22.105560     3135.676086     2948.790251
# 3           4.559753           4.230324      491.449066      596.162829
# 4           2.700840           6.497380      609.027708     1650.959482
#
#            ...           LACCESS_HISP15  PCT_LACCESS_HISP15  \
# 0          ...               471.136164            0.863345
# 1          ...              1377.874834            0.755973
# 2          ...               509.377525            1.855183
# 3          ...                 8.596762            0.037516
# 4          ...               497.489891            0.867886
#
#    LACCESS_NHASIAN15  PCT_LACCESS_NHASIAN15  LACCESS_NHNA15  \
# 0          86.767975               0.159000       61.169869
# 1         212.946378               0.116833      181.649648
# 2          17.096410               0.062266       39.960527
# 3           1.994318               0.008703        2.513097
# 4           8.428994               0.014705       28.938242
#
#    PCT_LACCESS_NHNA15  LACCESS_NHPI15  PCT_LACCESS_NHPI15  LACCESS_MULTIR15  \
# 0            0.112092        8.817961            0.016159        482.848633
# 1            0.099662       14.819634            0.008131       1127.696098
# 2            0.145539        8.082376            0.029436        462.382655
# 3            0.010967        0.000000            0.000000          5.259244
# 4            0.050484        1.062851            0.001854        202.914187
#
#    PCT_LACCESS_MULTIR15
# 0              0.884808
# 1              0.618712
# 2              1.684025
# 3              0.022951
# 4              0.353990
#
# [5 rows x 44 columns]

# %%
#combine all separate categories into one dataframe
# for simplicity. All categories have same number of rows
food = pd.concat(foodSep, axis=1)

# %%
#confirm combination
print(foodSep['ACCESS'].shape)
print(food.shape)
#things to investigate:
# sales to farmers
# food insecurity and very low food security
# adult diabetes and obesity rates
# Out:
# (3143, 44)
# (3143, 304)

# %%
#replace empty rows, which according to doc are empty info
# with proper NaN so we can visualize how much info we're missing
for index, row in food.iterrows():
    for k, i in food.items():
        if food.loc[index, k] == "":
            food.loc[index, k] = NaN

# %%
msno.matrix(food)

# %%
#Now that we see there's lots of info missing
# in some areas, lets find out which categories
# those areas correspond to
for k, i in food.items():
    print(k, sum(pd.isnull(food[k])))
# Out:
# ('ACCESS', 'FIPS') 0
# ('ACCESS', 'State') 0
# ('ACCESS', 'County') 0
# ('ACCESS', 'LACCESS_POP10') 0
# ('ACCESS', 'LACCESS_POP15') 19
# ('ACCESS', 'PCH_LACCESS_POP_10_15') 26
# ('ACCESS', 'PCT_LACCESS_POP10') 0
# ('ACCESS', 'PCT_LACCESS_POP15') 19
# ('ACCESS', 'LACCESS_LOWI10') 0
# ('ACCESS', 'LACCESS_LOWI15') 20
# ('ACCESS', 'PCH_LACCESS_LOWI_10_15') 28
# ('ACCESS', 'PCT_LACCESS_LOWI10') 0
# ('ACCESS', 'PCT_LACCESS_LOWI15') 20
# ('ACCESS', 'LACCESS_HHNV10') 0
# ('ACCESS', 'LACCESS_HHNV15') 3
# ('ACCESS', 'PCH_LACCESS_HHNV_10_15') 14
# ('ACCESS', 'PCT_LACCESS_HHNV10') 0
# ('ACCESS', 'PCT_LACCESS_HHNV15') 3
# ('ACCESS', 'LACCESS_SNAP15') 20
# ('ACCESS', 'PCT_LACCESS_SNAP15') 20
# ('ACCESS', 'LACCESS_CHILD10') 0
# ('ACCESS', 'LACCESS_CHILD15') 19
# ('ACCESS', 'LACCESS_CHILD_10_15') 28
# ('ACCESS', 'PCT_LACCESS_CHILD10') 0
# ('ACCESS', 'PCT_LACCESS_CHILD15') 19
# ('ACCESS', 'LACCESS_SENIORS10') 0
# ('ACCESS', 'LACCESS_SENIORS15') 19
# ('ACCESS', 'PCH_LACCESS_SENIORS_10_15') 26
# ('ACCESS', 'PCT_LACCESS_SENIORS10') 0
# ('ACCESS', 'PCT_LACCESS_SENIORS15') 19
# ('ACCESS', 'LACCESS_WHITE15') 19
# ('ACCESS', 'PCT_LACCESS_WHITE15') 19
# ('ACCESS', 'LACCESS_BLACK15') 19
# ('ACCESS', 'PCT_LACCESS_BLACK15') 19
# ('ACCESS', 'LACCESS_HISP15') 19
# ('ACCESS', 'PCT_LACCESS_HISP15') 19
# ('ACCESS', 'LACCESS_NHASIAN15') 19
# ('ACCESS', 'PCT_LACCESS_NHASIAN15') 19
# ('ACCESS', 'LACCESS_NHNA15') 19
# ('ACCESS', 'PCT_LACCESS_NHNA15') 19
# ('ACCESS', 'LACCESS_NHPI15') 19
# ('ACCESS', 'PCT_LACCESS_NHPI15') 19
# ('ACCESS', 'LACCESS_MULTIR15') 19
# ('ACCESS', 'PCT_LACCESS_MULTIR15') 19
# ('ASSISTANCE', 'FIPS') 0
# ('ASSISTANCE', 'State') 0
# ('ASSISTANCE', 'County') 0
# ('ASSISTANCE', 'REDEMP_SNAPS12') 242
# ('ASSISTANCE', 'REDEMP_SNAPS16') 174
# ('ASSISTANCE', 'PCH_REDEMP_SNAPS_12_16') 276
# ('ASSISTANCE', 'PCT_SNAP12') 0
# ('ASSISTANCE', 'PCT_SNAP16') 0
# ('ASSISTANCE', 'PCH_SNAP_12_16') 0
# ('ASSISTANCE', 'PC_SNAPBEN10') 83
# ('ASSISTANCE', 'PC_SNAPBEN15') 84
# ('ASSISTANCE', 'PCH_PC_SNAPBEN_10_15') 86
# ('ASSISTANCE', 'SNAP_PART_RATE08') 0
# ('ASSISTANCE', 'SNAP_PART_RATE13') 0
# ('ASSISTANCE', 'SNAP_OAPP09') 0
# ('ASSISTANCE', 'SNAP_OAPP16') 0
# ('ASSISTANCE', 'SNAP_CAP09') 0
# ('ASSISTANCE', 'SNAP_CAP16') 0
# ('ASSISTANCE', 'SNAP_BBCE09') 0
# ('ASSISTANCE', 'SNAP_BBCE16') 0
# ('ASSISTANCE', 'SNAP_REPORTSIMPLE09') 0
# ('ASSISTANCE', 'SNAP_REPORTSIMPLE16') 0
# ('ASSISTANCE', 'PCT_NSLP09') 0
# ('ASSISTANCE', 'PCT_NSLP15') 0
# ('ASSISTANCE', 'PCH_NSLP_09_15') 0
# ('ASSISTANCE', 'PCT_FREE_LUNCH09') 75
# ('ASSISTANCE', 'PCT_FREE_LUNCH14') 242
# ('ASSISTANCE', 'PCT_REDUCED_LUNCH09') 75
# ('ASSISTANCE', 'PCT_REDUCED_LUNCH14') 242
# ('ASSISTANCE', 'PCT_SBP09') 0
# ('ASSISTANCE', 'PCT_SBP15') 0
# ('ASSISTANCE', 'PCH_SBP_09_15') 0
# ('ASSISTANCE', 'PCT_SFSP09') 0
# ('ASSISTANCE', 'PCT_SFSP15') 0
# ('ASSISTANCE', 'PCH_SFSP_09_15') 0
# ('ASSISTANCE', 'PC_WIC_REDEMP08') 1064
# ('ASSISTANCE', 'PC_WIC_REDEMP12') 1139
# ('ASSISTANCE', 'PCH_PC_WIC_REDEMP_08_12') 1201
# ('ASSISTANCE', 'REDEMP_WICS08') 1064
# ('ASSISTANCE', 'REDEMP_WICS12') 1139
# ('ASSISTANCE', 'PCH_REDEMP_WICS_08_12') 1201
# ('ASSISTANCE', 'PCT_WIC09') 0
# ('ASSISTANCE', 'PCT_WIC15') 0
# ('ASSISTANCE', 'PCH_WIC_09_15') 0
# ('ASSISTANCE', 'PCT_CACFP09') 0
# ('ASSISTANCE', 'PCT_CACFP15') 0
# ('ASSISTANCE', 'PCH_CACFP_09_15') 0
# ('ASSISTANCE', 'FDPIR12') 0
# ('HEALTH', 'FIPS') 0
# ('HEALTH', 'State') 0
# ('HEALTH', 'County') 0
# ('HEALTH', 'PCT_DIABETES_ADULTS08') 5
# ('HEALTH', 'PCT_DIABETES_ADULTS13') 1
# ('HEALTH', 'PCT_OBESE_ADULTS08') 5
# ('HEALTH', 'PCT_OBESE_ADULTS13') 1
# ('HEALTH', 'PCT_HSPA15') 1118
# ('HEALTH', 'RECFAC09') 0
# ('HEALTH', 'RECFAC14') 0
# ('HEALTH', 'PCH_RECFAC_09_14') 123
# ('HEALTH', 'RECFACPTH09') 0
# ('HEALTH', 'RECFACPTH14') 0
# ('HEALTH', 'PCH_RECFACPTH_09_14') 123
# ('INSECURITY', 'FIPS') 0
# ('INSECURITY', 'State') 0
# ('INSECURITY', 'County') 0
# ('INSECURITY', 'FOODINSEC_10_12') 0
# ('INSECURITY', 'FOODINSEC_13_15') 0
# ('INSECURITY', 'CH_FOODINSEC_12_15') 0
# ('INSECURITY', 'VLFOODSEC_10_12') 0
# ('INSECURITY', 'VLFOODSEC_13_15') 0
# ('INSECURITY', 'CH_VLFOODSEC_12_15') 0
# ('INSECURITY', 'FOODINSEC_CHILD_01_07') 0
# ('INSECURITY', 'FOODINSEC_CHILD_03_11') 0
# ('LOCAL', 'FIPS') 0
# ('LOCAL', 'State') 0
# ('LOCAL', 'County') 0
# ('LOCAL', 'DIRSALES_FARMS07') 63
# ('LOCAL', 'DIRSALES_FARMS12') 63
# ('LOCAL', 'PCH_DIRSALES_FARMS_07_12') 124
# ('LOCAL', 'PCT_LOCLFARM07') 69
# ('LOCAL', 'PCT_LOCLFARM12') 68
# ('LOCAL', 'PCT_LOCLSALE07') 346
# ('LOCAL', 'PCT_LOCLSALE12') 287
# ('LOCAL', 'DIRSALES07') 288
# ('LOCAL', 'DIRSALES12') 242
# ('LOCAL', 'PCH_DIRSALES_07_12') 459
# ('LOCAL', 'PC_DIRSALES07') 288
# ('LOCAL', 'PC_DIRSALES12') 243
# ('LOCAL', 'PCH_PC_DIRSALES_07_12') 459
# ('LOCAL', 'FMRKT09') 6
# ('LOCAL', 'FMRKT16') 0
# ('LOCAL', 'PCH_FMRKT_09_16') 556
# ('LOCAL', 'FMRKTPTH09') 6
# ('LOCAL', 'FMRKTPTH16') 0
# ('LOCAL', 'PCH_FMRKTPTH_09_16') 556
# ('LOCAL', 'FMRKT_SNAP16') 895
# ('LOCAL', 'PCT_FMRKT_SNAP16') 895
# ('LOCAL', 'FMRKT_WIC16') 895
# ('LOCAL', 'PCT_FMRKT_WIC16') 895
# ('LOCAL', 'FMRKT_WICCASH16') 895
# ('LOCAL', 'PCT_FMRKT_WICCASH16') 895
# ('LOCAL', 'FMRKT_SFMNP16') 895
# ('LOCAL', 'PCT_FMRKT_SFMNP16') 895
# ('LOCAL', 'FMRKT_CREDIT16') 895
# ('LOCAL', 'PCT_FMRKT_CREDIT16') 895
# ('LOCAL', 'FMRKT_FRVEG16') 895
# ('LOCAL', 'PCT_FMRKT_FRVEG16') 895
# ('LOCAL', 'FMRKT_ANMLPROD16') 895
# ('LOCAL', 'PCT_FMRKT_ANMLPROD16') 895
# ('LOCAL', 'FMRKT_BAKED16') 895
# ('LOCAL', 'PCT_FMRKT_BAKED16') 895
# ('LOCAL', 'FMRKT_OTHERFOOD16') 895
# ('LOCAL', 'PCT_FMRKT_OTHERFOOD16') 895
# ('LOCAL', 'VEG_FARMS07') 63
# ('LOCAL', 'VEG_FARMS12') 63
# ('LOCAL', 'PCH_VEG_FARMS_07_12') 350
# ('LOCAL', 'VEG_ACRES07') 611
# ('LOCAL', 'VEG_ACRES12') 562
# ('LOCAL', 'PCH_VEG_ACRES_07_12') 1083
# ('LOCAL', 'VEG_ACRESPTH07') 611
# ('LOCAL', 'VEG_ACRESPTH12') 612
# ('LOCAL', 'PCH_VEG_ACRESPTH_07_12') 898
# ('LOCAL', 'FRESHVEG_FARMS07') 63
# ('LOCAL', 'FRESHVEG_FARMS12') 63
# ('LOCAL', 'PCH_FRESHVEG_FARMS_07_12') 364
# ('LOCAL', 'FRESHVEG_ACRES07') 1300
# ('LOCAL', 'FRESHVEG_ACRES12') 1226
# ('LOCAL', 'PCH_FRESHVEG_ACRES_07_12') 2091
# ('LOCAL', 'FRESHVEG_ACRESPTH07') 1300
# ('LOCAL', 'FRESHVEG_ACRESPTH12') 1227
# ('LOCAL', 'PCH_FRESHVEG_ACRESPTH_07_12') 2091
# ('LOCAL', 'ORCHARD_FARMS07') 63
# ('LOCAL', 'ORCHARD_FARMS12') 63
# ('LOCAL', 'PCH_ORCHARD_FARMS_07_12') 423
# ('LOCAL', 'ORCHARD_ACRES07') 548
# ('LOCAL', 'ORCHARD_ACRES12') 596
# ('LOCAL', 'PCH_ORCHARD_ACRES_07_12') 1122
# ('LOCAL', 'ORCHARD_ACRESPTH07') 548
# ('LOCAL', 'ORCHARD_ACRESPTH12') 597
# ('LOCAL', 'PCH_ORCHARD_ACRESPTH_07_12') 1122
# ('LOCAL', 'BERRY_FARMS07') 63
# ('LOCAL', 'BERRY_FARMS12') 63
# ('LOCAL', 'PCH_BERRY_FARMS_07_12') 907
# ('LOCAL', 'BERRY_ACRES07') 838
# ('LOCAL', 'BERRY_ACRES12') 809
# ('LOCAL', 'PCH_BERRY_ACRES_07_12') 1870
# ('LOCAL', 'BERRY_ACRESPTH07') 838
# ('LOCAL', 'BERRY_ACRESPTH12') 810
# ('LOCAL', 'PCH_BERRY_ACRESPTH_07_12') 1870
# ('LOCAL', 'SLHOUSE07') 1
# ('LOCAL', 'SLHOUSE12') 1
# ('LOCAL', 'PCH_SLHOUSE_07_12') 166
# ('LOCAL', 'GHVEG_FARMS07') 63
# ('LOCAL', 'GHVEG_FARMS12') 63
# ('LOCAL', 'PCH_GHVEG_FARMS_07_12') 1942
# ('LOCAL', 'GHVEG_SQFT07') 843
# ('LOCAL', 'GHVEG_SQFT12') 895
# ('LOCAL', 'PCH_GHVEG_SQFT_07_12') 2801
# ('LOCAL', 'GHVEG_SQFTPTH07') 843
# ('LOCAL', 'GHVEG_SQFTPTH12') 896
# ('LOCAL', 'PCH_GHVEG_SQFTPTH_07_12') 2801
# ('LOCAL', 'FOODHUB16') 0
# ('LOCAL', 'CSA07') 63
# ('LOCAL', 'CSA12') 63
# ('LOCAL', 'PCH_CSA_07_12') 796
# ('LOCAL', 'AGRITRSM_OPS07') 63
# ('LOCAL', 'AGRITRSM_OPS12') 63
# ('LOCAL', 'PCH_AGRITRSM_OPS_07_12') 426
# ('LOCAL', 'AGRITRSM_RCT07') 1169
# ('LOCAL', 'AGRITRSM_RCT12') 1024
# ('LOCAL', 'PCH_AGRITRSM_RCT_07_12') 1876
# ('LOCAL', 'FARM_TO_SCHOOL09') 5
# ('LOCAL', 'FARM_TO_SCHOOL13') 208
# ('PRICES_TAXES', 'FIPS') 0
# ('PRICES_TAXES', 'State') 0
# ('PRICES_TAXES', 'County') 0
# ('PRICES_TAXES', 'MILK_PRICE10') 34
# ('PRICES_TAXES', 'SODA_PRICE10') 34
# ('PRICES_TAXES', 'MILK_SODA_PRICE10') 34
# ('PRICES_TAXES', 'SODATAX_STORES14') 0
# ('PRICES_TAXES', 'SODATAX_VENDM14') 0
# ('PRICES_TAXES', 'CHIPSTAX_STORES14') 0
# ('PRICES_TAXES', 'CHIPSTAX_VENDM14') 0
# ('PRICES_TAXES', 'FOOD_TAX14') 0
# ('RESTAURANTS', 'FIPS') 0
# ('RESTAURANTS', 'State') 0
# ('RESTAURANTS', 'County') 0
# ('RESTAURANTS', 'FFR09') 0
# ('RESTAURANTS', 'FFR14') 0
# ('RESTAURANTS', 'PCH_FFR_09_14') 51
# ('RESTAURANTS', 'FFRPTH09') 0
# ('RESTAURANTS', 'FFRPTH14') 0
# ('RESTAURANTS', 'PCH_FFRPTH_09_14') 46
# ('RESTAURANTS', 'FSR09') 0
# ('RESTAURANTS', 'FSR14') 0
# ('RESTAURANTS', 'PCH_FSR_09_14') 36
# ('RESTAURANTS', 'FSRPTH09') 0
# ('RESTAURANTS', 'FSRPTH14') 0
# ('RESTAURANTS', 'PCH_FSRPTH_09_14') 31
# ('RESTAURANTS', 'PC_FFRSALES07') 0
# ('RESTAURANTS', 'PC_FFRSALES12') 0
# ('RESTAURANTS', 'PC_FSRSALES07') 0
# ('RESTAURANTS', 'PC_FSRSALES12') 0
# ('SOCIOECONOMIC', 'FIPS') 0
# ('SOCIOECONOMIC', 'State') 0
# ('SOCIOECONOMIC', 'County') 0
# ('SOCIOECONOMIC', 'PCT_NHWHITE10') 0
# ('SOCIOECONOMIC', 'PCT_NHBLACK10') 0
# ('SOCIOECONOMIC', 'PCT_HISP10') 0
# ('SOCIOECONOMIC', 'PCT_NHASIAN10') 0
# ('SOCIOECONOMIC', 'PCT_NHNA10') 0
# ('SOCIOECONOMIC', 'PCT_NHPI10') 0
# ('SOCIOECONOMIC', 'PCT_65OLDER10') 0
# ('SOCIOECONOMIC', 'PCT_18YOUNGER10') 0
# ('SOCIOECONOMIC', 'MEDHHINC15') 4
# ('SOCIOECONOMIC', 'POVRATE15') 4
# ('SOCIOECONOMIC', 'PERPOV10') 0
# ('SOCIOECONOMIC', 'CHILDPOVRATE15') 4
# ('SOCIOECONOMIC', 'PERCHLDPOV10') 0
# ('SOCIOECONOMIC', 'METRO13') 0
# ('SOCIOECONOMIC', 'POPLOSS10') 2
# ('STORES', 'FIPS') 0
# ('STORES', 'State') 0
# ('STORES', 'County') 0
# ('STORES', 'GROC09') 0
# ('STORES', 'GROC14') 0
# ('STORES', 'PCH_GROC_09_14') 20
# ('STORES', 'GROCPTH09') 0
# ('STORES', 'GROCPTH14') 0
# ('STORES', 'PCH_GROCPTH_09_14') 15
# ('STORES', 'SUPERC09') 0
# ('STORES', 'SUPERC14') 0
# ('STORES', 'PCH_SUPERC_09_14') 140
# ('STORES', 'SUPERCPTH09') 0
# ('STORES', 'SUPERCPTH14') 0
# ('STORES', 'PCH_SUPERCPTH_09_14') 139
# ('STORES', 'CONVS09') 0
# ('STORES', 'CONVS14') 0
# ('STORES', 'PCH_CONVS_09_14') 24
# ('STORES', 'CONVSPTH09') 0
# ('STORES', 'CONVSPTH14') 0
# ('STORES', 'PCH_CONVSPTH_09_14') 19
# ('STORES', 'SPECS09') 0
# ('STORES', 'SPECS14') 0
# ('STORES', 'PCH_SPECS_09_14') 192
# ('STORES', 'SPECSPTH09') 0
# ('STORES', 'SPECSPTH14') 0
# ('STORES', 'PCH_SPECSPTH_09_14') 188
# ('STORES', 'SNAPS12') 0
# ('STORES', 'SNAPS16') 0
# ('STORES', 'PCH_SNAPS_12_16') 3
# ('STORES', 'SNAPSPTH12') 0
# ('STORES', 'SNAPSPTH16') 2
# ('STORES', 'PCH_SNAPSPTH_12_16') 5
# ('STORES', 'WICS08') 0
# ('STORES', 'WICS12') 0
# ('STORES', 'PCH_WICS_08_12') 19
# ('STORES', 'WICSPTH08') 0
# ('STORES', 'WICSPTH12') 0
# ('STORES', 'PCH_WICSPTH_08_12') 19
